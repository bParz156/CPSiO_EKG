# %%
import matplotlib.pyplot as plt # type: ignore
import numpy as np # type: ignore

margin=0.05

def readFile(filename, frequency, hasFirstTime):
    timePeriod = 1 / frequency
    global xarray, valuesArray, numberOfCases
    
    xarray.clear()
    valuesArray.clear()
    try:
        with open(filename, 'r') as file:
            for line in file:
                columns = line.split()
                if hasFirstTime and len(columns) > 1:
                    xarray.append(float(columns[0]))
                    columns = columns[1:]  # Usun istniejaca kolumne
                else:
                    xarray.append(len(xarray) * timePeriod)
                
                for i, value in enumerate(columns):
                    if len(valuesArray) <= i:
                        valuesArray.append([])  #Stworz nowa liste
                    valuesArray[i].append(float(value))
                    
        numberOfCases = len(valuesArray)
        return True
    except Exception as e:
        with out:
            print("Błąd odczytu pliku", str(e))
        return False

def fourierIOdwrotny(x, time,fs, nazwa, k=1000, eliminate0=True):
    #sygnal
    T=1/fs
    plt.figure()
    plt.plot(time[:k],x[:k])
    plt.title(nazwa)
    plt.xlabel('Czas [s]')
    plt.ylabel('Amplituda')
    plt.tight_layout()
    plt.grid(True)
    plt.show()
    
    #fourier
    n=len(x)
    fourier=np.fft.fft(x)
    freq_axis = np.fft.fftfreq(n, d=1/fs)
    modul=abs(fourier)
    #modul2=modul
    modul[0]=modul[1]
    plt.figure()
    plt.plot(freq_axis, modul)
    plt.title('Widmo amplitudowe sygnału - '+ nazwa)
    plt.xlabel('Częstotliwość [Hz]')
    plt.ylabel('Amplituda')
    plt.tight_layout()
    plt.grid(True)
    xmin, xmax = 0, fs/2  # Desired domain
    xmargin = (xmax - xmin) * margin
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.show()
    
    #transformata odwrotna
    odwrotna= np.fft.ifft(fourier)
    modulOdwrotna=abs(odwrotna)
    modulFunkcji=[abs(ele) for ele in x]
    roznica=modulOdwrotna-modulFunkcji

    plt.subplot(1, 2, 1)
    plt.plot(time[:k],modulFunkcji[:k])
    plt.title(nazwa)
    plt.xlabel('Czas [s]')
    plt.ylabel('Amplituda')
    plt.title('Oryginalny')
    plt.subplot(1, 2, 2)
    plt.plot(time[:k],modulOdwrotna[:k])
    plt.title(nazwa)
    plt.xlabel('Czas [s]')
    plt.ylabel('Amplituda')
    plt.title('Po transformacie')
    
    plt.figure()
    plt.plot(time[:k], roznica[:k])
    plt.title('Roznica między oryginalem a transformata odwrotna - '+  nazwa)
    plt.xlabel('Czas [s]')
    plt.ylabel('Amplituda')
    plt.grid(True)
    plt.show()


"""
x- sygnal oryginalny
t- wektro czasu
fs- czestotliwosc probkowania
cutoffFrequency - czestotliwosc odciecia
w i h parametry filtra
"""
def ilustrujFiltrowanie(x, t, fs , cutoffFrequency, w, h, nazwaFiltra ):
    fourier=np.fft.fft(x)
    fourier[0]=fourier[1]
    n=len(x)
    h=np.array([(0.001 if (i==0) else i) for i in h])
    freq_axis=np.fft.fftfreq(n, d=1/fs)
    plt.plot(w,20*np.log10(abs(h)))
    plt.title('Charakterystyka: '+nazwaFiltra)
    plt.xlabel('Czestotliwosc [radian / s]')
    plt.ylabel('Amplituda [dB]')
    plt.margins(0, 0.1)
    plt.grid(which='both', axis='both')
    plt.axvline(cutoffFrequency, color='green', label='Czestoliwosc odciecia') # cutoff frequency
    plt.legend()
    plt.xlim(0-margin, )
    plt.show()
    
    filtering=fourier*h
    filtered=np.fft.ifft(filtering)
    
    plt.figure()
    plt.plot(freq_axis, abs(fourier), '-r', label='Widmo oryginalne')
    plt.plot(freq_axis,abs(filtering), '-b', label='Widmo filtrowane')
    plt.legend()
    xmin, xmax = 0, fs/2  # Desired domain
    xmargin = (xmax - xmin) * margin
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.xlabel("Czestotliwosc [Hz]")
    plt.ylabel("Amplituda")
    plt.title("Porównanie widma")
    plt.show()

    """
    plt.figure()
    plt.subplot(1,2,1)
    plt.plot(freq_axis, abs(fourier))
    plt.xlabel('Czestotliwosc [Hz]')
    plt.ylabel('Amplituda')
    xmin, xmax = 0, fs/2  # Desired domain
    xmargin = (xmax - xmin) * margin
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.title('Widmo oryginalne')
    plt.subplot(1,2,2)
    plt.plot(freq_axis,abs(filtering))
    plt.xlabel('Czestotliwosc [Hz]')
    plt.ylabel('Amplituda')
    xmin, xmax = 0, fs/2  # Desired domain
    xmargin = (xmax - xmin) * margin
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.title('Widmo wyfiltrowane')
    """
    
    plt.figure()
    plt.plot(t, x , 'r',label='oryginalny')
    plt.plot(t, filtered, 'b',label='wyfiltrowany')
    plt.legend()
    plt.title("Porównanie sygnału w dziedzinie czasu")
    plt.show()

    return filtered

# %%
# %run methods.ipynb
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3515, in run_ast_nodes
#     code = compiler(mod, cell_name, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\codeop.py", line 118, in __call__
#     codeob = compile(source, filename, symbol, self.flags, True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while traversing 'expr' node
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3515, in run_ast_nodes
#     code = compiler(mod, cell_name, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\codeop.py", line 118, in __call__
#     codeob = compile(source, filename, symbol, self.flags, True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while traversing 'expr' node
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1133, in get_records
#     style = get_style_by_name(self._tb_highlight_style)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\styles\__init__.py", line 45, in get_style_by_name
#     mod = __import__(mod, None, None, [cls])
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1351, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 418, in __enter__
#   File "<frozen importlib._bootstrap>", line 311, in acquire
#   File "<frozen importlib._bootstrap>", line 170, in __enter__
#   File "<frozen importlib._bootstrap>", line 132, in setdefault
#   File "<frozen importlib._bootstrap>", line 75, in __new__
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 183, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 781, in __init__
#     context = TracebackException(
#               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 707, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 441, in _extract_from_extended_frame_gen
#     f.line
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 326, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1107, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 989, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 801, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\executing\executing.py", line 108, in only
#     if isinstance(it, Sized):
#        ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\typing.py", line 1169, in __instancecheck__
#     return self.__subclasscheck__(type(obj))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\typing.py", line 1443, in __subclasscheck__
#     return issubclass(cls, self.__origin__)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen abc>", line 123, in __subclasscheck__
#   File "<frozen abc>", line 123, in __subclasscheck__
# RecursionError: maximum recursion depth exceeded
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3515, in run_ast_nodes
#     code = compiler(mod, cell_name, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\codeop.py", line 118, in __call__
#     codeob = compile(source, filename, symbol, self.flags, True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while traversing 'expr' node
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1133, in get_records
#     style = get_style_by_name(self._tb_highlight_style)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\styles\__init__.py", line 45, in get_style_by_name
#     mod = __import__(mod, None, None, [cls])
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1351, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 418, in __enter__
#   File "<frozen importlib._bootstrap>", line 311, in acquire
#   File "<frozen importlib._bootstrap>", line 170, in __enter__
#   File "<frozen importlib._bootstrap>", line 132, in setdefault
#   File "<frozen importlib._bootstrap>", line 75, in __new__
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 183, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 781, in __init__
#     context = TracebackException(
#               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 707, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 441, in _extract_from_extended_frame_gen
#     f.line
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 326, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 575, in _process_state
#     rex = cls._process_regex(tdef[0], rflags, state)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 503, in _process_regex
#     regex = regex.get()
#             ^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 491, in get
#     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 91, in regex_opt
#     return prefix + regex_opt_inner(strings, '(') + suffix
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1107, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 988, in format_record
#     _format_traceback_lines(
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 215, in _format_traceback_lines
#     line = stack_line.render(pygmented=has_colors).rstrip('\n') + '\n'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 391, in render
#     start_line, lines = self.frame_info._pygmented_scope_lines
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 824, in _pygmented_scope_lines
#     lines = _pygmented_with_ranges(formatter, code, ranges)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 155, in _pygmented_with_ranges
#     class MyLexer(type(get_lexer_by_name("python3"))):
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexers\__init__.py", line 127, in get_lexer_by_name
#     return _lexer_cache[name](**options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 657, in __call__
#     cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 596, in process_tokendef
#     cls._process_state(tokendefs, processed, state)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 559, in _process_state
#     tokens.extend(cls._process_state(unprocessed, processed,
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 577, in _process_state
#     raise ValueError("uncompilable regex %r in state %r of %r: %s" %
# ValueError: uncompilable regex <pygments.lexer.words object at 0x000002751569D220> in state 'keywords' of <class 'pygments.lexers.python.PythonLexer'>: maximum recursion depth exceeded
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3515, in run_ast_nodes
#     code = compiler(mod, cell_name, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\codeop.py", line 118, in __call__
#     codeob = compile(source, filename, symbol, self.flags, True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded while traversing 'expr' node
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1133, in get_records
#     style = get_style_by_name(self._tb_highlight_style)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\styles\__init__.py", line 45, in get_style_by_name
#     mod = __import__(mod, None, None, [cls])
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1351, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 418, in __enter__
#   File "<frozen importlib._bootstrap>", line 311, in acquire
#   File "<frozen importlib._bootstrap>", line 170, in __enter__
#   File "<frozen importlib._bootstrap>", line 132, in setdefault
#   File "<frozen importlib._bootstrap>", line 75, in __new__
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Joanna\AppData\Local\Temp\ipykernel_14676\719945540.py", line 1, in <module>
#     get_ipython().run_line_magic('run', 'methods.ipynb')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2480, in run_line_magic
#     result = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py", line 737, in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3005, in safe_execfile_ipy
#     result.raise_error()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 308, in raise_error
#     raise self.error_in_exec
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#              ^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3536, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2176, in showtraceback
#     traceback.print_exc()
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 183, in print_exc
#     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 124, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 781, in __init__
#     context = TracebackException(
#               ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 707, in __init__
#     self.stack = StackSummary._extract_from_extended_frame_gen(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 441, in _extract_from_extended_frame_gen
#     f.line
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\traceback.py", line 326, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 575, in _process_state
#     rex = cls._process_regex(tdef[0], rflags, state)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 503, in _process_regex
#     regex = regex.get()
#             ^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 491, in get
#     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 91, in regex_opt
#     return prefix + regex_opt_inner(strings, '(') + suffix
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in <genexpr>
#     '|'.join(regex_opt_inner(list(group[1]), '')
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py", line 77, in regex_opt_inner
#     '|'.join(regex_opt_inner(list(group[1]), '')
# RecursionError: maximum recursion depth exceeded
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 2168, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1454, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1345, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1192, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 1107, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 988, in format_record
#     _format_traceback_lines(
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py", line 215, in _format_traceback_lines
#     line = stack_line.render(pygmented=has_colors).rstrip('\n') + '\n'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 391, in render
#     start_line, lines = self.frame_info._pygmented_scope_lines
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\core.py", line 824, in _pygmented_scope_lines
#     lines = _pygmented_with_ranges(formatter, code, ranges)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\stack_data\utils.py", line 155, in _pygmented_with_ranges
#     class MyLexer(type(get_lexer_by_name("python3"))):
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexers\__init__.py", line 127, in get_lexer_by_name
#     return _lexer_cache[name](**options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 657, in __call__
#     cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 596, in process_tokendef
#     cls._process_state(tokendefs, processed, state)
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 559, in _process_state
#     tokens.extend(cls._process_state(unprocessed, processed,
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\lexer.py", line 577, in _process_state
#     raise ValueError("uncompilable regex %r in state %r of %r: %s" %
# ValueError: uncompilable regex <pygments.lexer.words object at 0x000002751569D220> in state 'keywords' of <class 'pygments.lexers.python.PythonLexer'>: maximum recursion depth exceeded
# Traceback (most recent call last):
#   File "C:\Users\Joanna\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py", line 3515, in run_ast_nodes
#     code = compiler(mod, cell_name, mode)
# ...
#     117 def __call__(self, source, filename, symbol):
# --> 118     codeob = compile(source, filename, symbol, self.flags, True)
#     119     for feature in _features:
#
# RecursionError: maximum recursion depth exceeded while traversing 'expr' node
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2168, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2167     else:
# -> 2168         stb = self.InteractiveTB.structured_traceback(
#    2169             etype, value, tb, tb_offset=tb_offset
#    2170         )
#    2172 except Exception:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py:1454, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1453     self.tb = etb
# -> 1454 return FormattedTB.structured_traceback(
#    1455     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1456 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py:1345, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1343 if mode in self.verbose_modes:
#    1344     # Verbose modes need a full traceback
# -> 1345     return VerboseTB.structured_traceback(
#    1346         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1347     )
#    1348 elif mode == 'Minimal':
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py:1192, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191 """Return a nice text document describing the traceback."""
# -> 1192 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                        tb_offset)
#    1195 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py:1082, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080 head = self.prepare_header(str(etype), self.long_header)
#    1081 records = (
# -> 1082     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1083 )
#    1085 frames = []
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\ultratb.py:1133, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1132 if self.has_colors:
# -> 1133     style = get_style_by_name(self._tb_highlight_style)
#    1134     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\styles\__init__.py:45, in get_style_by_name(name)
#      44 try:
# ---> 45     mod = __import__(mod, None, None, [cls])
#      46 except ImportError:
#
# File <frozen importlib._bootstrap>:1351, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:418, in __enter__(self)
#
# File <frozen importlib._bootstrap>:311, in acquire(self)
#
# File <frozen importlib._bootstrap>:170, in __enter__(self)
#
# File <frozen importlib._bootstrap>:132, in setdefault(self, key, default)
#
# File <frozen importlib._bootstrap>:75, in __new__(type, ob, key)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'methods.ipynb')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'methods.ipynb')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping similar frames: <module> at line 1 (49 times), ExecutionResult.raise_error at line 308 (49 times), ExecutionMagics.run at line 737 (49 times), InteractiveShell.run_code at line 3577 (49 times), InteractiveShell.run_line_magic at line 2480 (49 times), InteractiveShell.safe_execfile_ipy at line 3005 (49 times)]
#
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'methods.ipynb')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3130, in InteractiveShell._run_cell(self, raw_cell, store_history, silent, shell_futures, cell_id)
#    3127     runner = _pseudo_sync_runner
#    3129 try:
# -> 3130     result = runner(coro)
#    3131 except BaseException as e:
#    3132     info = ExecutionInfo(
#    3133         raw_cell, store_history, silent, shell_futures, cell_id
#    3134     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3334, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3330 # Execute the user code
#    3331 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3334 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3335        interactivity=interactivity, compiler=compiler, result=result)
#    3337 self.last_execution_succeeded = not has_raised
#    3338 self.last_execution_result = result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:3536, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3534     if result:
#    3535         result.error_before_exec = sys.exc_info()[1]
# -> 3536     self.showtraceback()
#    3537     return True
#    3539 return False
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:2176, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2172 except Exception:
#    2173     print(
#    2174         "Unexpected exception formatting exception. Falling back to standard exception"
#    2175     )
# -> 2176     traceback.print_exc()
#    2177     return None
#    2179 self._showtraceback(etype, value, stb)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:183, in print_exc(limit, file, chain)
#     181 def print_exc(limit=None, file=None, chain=True):
#     182     """Shorthand for 'print_exception(sys.exception(), limit, file, chain)'."""
# --> 183     print_exception(sys.exception(), limit=limit, file=file, chain=chain)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:124, in print_exception(exc, value, tb, limit, file, chain)
#     113 """Print exception up to 'limit' stack trace entries from 'tb' to 'file'.
#     114
#     115 This differs from print_tb() in the following ways: (1) if
#    (...)
#     121 position of the error.
#     122 """
#     123 value, tb = _parse_value_tb(exc, value, tb)
# --> 124 te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#     125 te.print(file=file, chain=chain)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:781, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     778     need_context = True
#     779 if (e and e.__context__ is not None
#     780     and need_context and id(e.__context__) not in _seen):
# --> 781     context = TracebackException(
#     782         type(e.__context__),
#     783         e.__context__,
#     784         e.__context__.__traceback__,
#     785         limit=limit,
#     786         lookup_lines=lookup_lines,
#     787         capture_locals=capture_locals,
#     788         max_group_width=max_group_width,
#     789         max_group_depth=max_group_depth,
#     790         _seen=_seen)
#     791 else:
#     792     context = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:707, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     704 self.max_group_width = max_group_width
#     705 self.max_group_depth = max_group_depth
# --> 707 self.stack = StackSummary._extract_from_extended_frame_gen(
#     708     _walk_tb_with_full_positions(exc_traceback),
#     709     limit=limit, lookup_lines=lookup_lines,
#     710     capture_locals=capture_locals)
#     711 self.exc_type = exc_type
#     712 # Capture now to permit freeing resources: only complication is in the
#     713 # unofficial API _format_final_exc_line
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:441, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     439 if lookup_lines:
#     440     for f in result:
# --> 441         f.line
#     442 return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\traceback.py:326, in FrameSummary.line(self)
#     324     if self.lineno is None:
#     325         return None
# --> 326     self._line = linecache.getline(self.filename, self.lineno)
#     327 return self._line.strip()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except (OSError, UnicodeDecodeError, SyntaxError):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
