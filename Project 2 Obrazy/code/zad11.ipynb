# %%
# %run functions.ipynb
from ipywidgets import interact
import ipywidgets as widgets
data_path="../data/"
images= ["circuitmask.png","characters_test_pattern.png"]

filename=widgets.Dropdown(
    options=images,
    value=images[0],
    description='Obraz:',
    disabled=False,
)
display(filename)
# Out:
# Dropdown(description='Obraz:', options=('circuitmask.png', 'characters_test_pattern.png'), value='circuitmask.…

# %%
image_path=data_path+filename.value
#interact(sobel_filter, image_path=data_path+filename)
sobel_filter(image_path)

# %%
image_path=data_path+"blurry-moon.tif"
laplace_filter(image_path)

# %%
image_path=data_path+"text-dipxe-blurred.tif"
unsharp_masking(image_path)
