# %%
# %run functions.ipynb
data_path='../data/'

files=["chest-xray.png", "pollen-dark.png", "pollen-ligt.png", "pollen-lowcontrast.png", "pout.png", "spectrum.png"]

for file in files:
    print(file)
    image_path = data_path+file
    wyrownaj_histogram(image_path)
# Out:
# chest-xray.png
# pollen-dark.png
# pollen-ligt.png
# pollen-lowcontrast.png
# pout.png
# spectrum.png
